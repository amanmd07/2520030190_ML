# %% [markdown]
# Program 1: Variables and Data Types Write a Python program to declare variables of type int, float, string, and boolean, and display their values along with their data types. Write a program to check the data type of different variables using the type() function. Modify the values of the variables and observe how their data types change. Create your own variables representing a student's details and print their values and data types.

# %%
# Declaring variables
num = 25
price = 99.99
name = "Pragnya"
is_student = True

# Displaying values
print("Integer Value:", num)
print("Float Value:", price)
print("String Value:", name)
print("Boolean Value:", is_student)

# Displaying data types
print("\nData Types:")
print(type(num))
print(type(price))
print(type(name))
print(type(is_student))
# Out:
# Integer Value: 25
# Float Value: 99.99
# String Value: Pragnya
# Boolean Value: True
#
# Data Types:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Program 2: Operators Write a Python program to demonstrate arithmetic operators. Write a program to demonstrate comparison operators using two numbers. Write a program to demonstrate logical operators (and, or, not). Write a program to determine whether a student is eligible for placement based on CGPA and attendance using logical operators.

# %%
#--ARTHEMATIC OPERATORS--#
a = 7
b = 3
print("a + b = ", a + b)
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a % b =", a % b)
#---COMPARISION OPERATORS--#
print("a == b =", a == b)
print("a != b =", a != b)
print("a > b =", a > b)
print("a < b =", a < b)
print("a >= b =", a >= b)
print("a <= b =", a <= b)

#--LOGICAL OPERATORS--#
print("\nLogical Operators")
print("(a > b) and (a > 5) =", (a > b) and (a > 5))
print("(a < b) or (a > 5) =", (a < b) or (a > 5))
print("not(a > b) =", not(a > b))


cgpa = 8.2
attendance = 80

print("\nPlacement Eligibility")
print("CGPA =", cgpa)
print("Attendance =", attendance)
print("Eligible =", (cgpa >= 7.5) and (attendance >= 75))
# Out:
# a + b =  10
# a + b = 10
# a - b = 4
# a * b = 21
# a / b = 2.3333333333333335
# a % b = 1
# a == b = False
# a != b = True
# a > b = True
# a < b = False
# a >= b = True
# a <= b = False
#
# Logical Operators
# (a > b) and (a > 5) = True
# (a < b) or (a > 5) = True
# not(a > b) = False
#
# Placement Eligibility
# CGPA = 8.2
# Attendance = 80
# Eligible = True

# %%
model_name = "Logistic Regression"
accuracy = 0.87345

# Old, clunky way (avoid this):
print("Accuracy of " + model_name + " is " + str(accuracy))

# f-string way (use this):
print(f"Accuracy of {model_name} is {accuracy}")

# ':.3f' inside the braces rounds a float to 3 decimal places -
# you will use this in almost every experiment to print clean metrics.
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.873

# %% [markdown]
# Program 4: Lists and Indexing Write a Python program to create a list and access its elements using indexing. Write a program to display the first, second, and last elements of a list. Write a program to demonstrate list slicing. Write a program to add a new element to an existing list using the append() method. Write a program to display the total number of elements in a list.

# %%
fruits = ["Apple", "Banana", "Mango", "Orange", "Grapes"]

# Access elements using indexing
print("List =", fruits)
print("First element =", fruits[0])
print("Second element =", fruits[1])
print("Last element =", fruits[-1])

# List slicing
print("First three elements =", fruits[:3])
print("Last two elements =", fruits[3:])

# Add a new element
fruits.append("Pineapple")
print("After append =", fruits)

# Total number of elements
print("Total elements =", len(fruits))
# Out:
# List = ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes']
# First element = Apple
# Second element = Banana
# Last element = Grapes
# First three elements = ['Apple', 'Banana', 'Mango']
# Last two elements = ['Orange', 'Grapes']
# After append = ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes', 'Pineapple']
# Total elements = 6

# %% [markdown]
# Program 5: Dictionaries Write a Python program to create a dictionary and display all its key-value pairs. Write a program to access the value associated with a specific key in a dictionary. Write a program to iterate through a dictionary using the items() method. Write a program to store different machine learning models in a dictionary and display their names and objects.

# %%
# Create a dictionary
student = {
    "Name": "Pragnya",
    "Roll No": 101,
    "CGPA": 9.2
}

# Display all key-value pairs
print("Student Dictionary =", student)

# Access value using a key
print("Student Name =", student["Name"])

# Iterate through the dictionary
print("\nDictionary Elements")
for key, value in student.items():
    print(key, ":", value)

# Machine Learning Models Dictionary
models = {
    "Linear Regression": "Model 1",
    "Decision Tree": "Model 2",
    "Random Forest": "Model 3",
    "SVM": "Model 4"
}

print("\nMachine Learning Models")
for name, obj in models.items():
    print(name, "=", obj)
# Out:
# Student Dictionary = {'Name': 'Pragnya', 'Roll No': 101, 'CGPA': 9.2}
# Student Name = Pragnya
#
# Dictionary Elements
# Name : Pragnya
# Roll No : 101
# CGPA : 9.2
#
# Machine Learning Models
# Linear Regression = Model 1
# Decision Tree = Model 2
# Random Forest = Model 3
# SVM = Model 4

# %% [markdown]
# Program 6: Conditional Statements
# Write a Python program to classify a student's CGPA into High, Mid, or Low categories using if-elif-else.
# Write a program to check whether missing values are present in a dataset using conditional statements.
# Write a program to determine whether a student is eligible for placement based on CGPA.
# Write a program that uses if-elif-else to assign grades based on marks.

# %%
# Program 6: Conditional Statements

# 1. Classify CGPA
cgpa = 8.2

if cgpa >= 8.5:
    print("High")
elif cgpa >= 6.5:
    print("Mid")
else:
    print("Low")

# 2. Check Missing Values
value = None

if value == None:
    print("Missing values are present")
else:
    print("No missing values")

# 3. Placement Eligibility
cgpa = 8.2

if cgpa >= 7.5:
    print("Eligible for Placement")
else:
    print("Not Eligible for Placement")

# 4. Grade Based on Marks
marks = 85

if marks >= 90:
    print("Grade A+")
elif marks >= 80:
    print("Grade A")
elif marks >= 70:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
else:
    print("Fail")
# Out:
# Mid
# Missing values are present
# Eligible for Placement
# Grade A

# %% [markdown]
# Program 7: Loops Write a Python program to display all elements in a list using a for loop. Write a program to calculate the average of numbers stored in a list. Write a program to display only the values greater than a given threshold using a loop. Write a program to find the maximum and minimum values in a list using loops. Write a program to count the number of elements satisfying a given condition using a loop.

# %%
# Program 7: Loops

numbers = [10, 20, 30, 40, 50]

# Display all elements
print("List elements:")
for i in numbers:
    print(i)

# Average of numbers
sum = 0
for i in numbers:
    sum = sum + i
print("Average =", sum / len(numbers))

# Values greater than threshold
threshold = 25
print("Values greater than", threshold)
for i in numbers:
    if i > threshold:
        print(i)

# Maximum and Minimum
max = numbers[0]
min = numbers[0]

for i in numbers:
    if i > max:
        max = i
    if i < min:
        min = i

print("Maximum =", max)
print("Minimum =", min)

# Count elements greater than 25
count = 0
for i in numbers:
    if i > 25:
        count = count + 1

print("Count =", count)
# Out:
# List elements:
# 10
# 20
# 30
# 40
# 50
# Average = 30.0
# Values greater than 25
# 30
# 40
# 50
# Maximum = 50
# Minimum = 10
# Count = 3
